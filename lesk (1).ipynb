# %%
import nltk
nltk.download('wordnet')

from nltk.corpus import wordnet
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
import sys

stop_words = set(line.strip() for line in open('C:/Users/janvi/Desktop/stopwords.txt'))

def simplified_lesk( word, sentence ):
    final = None
    maxoverlap = 0
    word=wordnet.morphy(word)

    print("Total senses are")
    print("------------------------")
    for sense in wordnet.synsets(word):
        print (sense)
        overlap = overlap_func(sense,sentence)
        for hyponyms in sense.hyponyms():
            overlap += overlap_func( hyponyms, sentence )

        if overlap > maxoverlap:
                maxoverlap = overlap
                final = sense
        print (overlap)
    print ("--------------------------------")
    print("\nFinal Chosen Sense")
    return final

def overlap_func( synset, sentence ):
    x=synset.definition()
    gloss = set(tokenizer.tokenize(x))
    for example in synset.examples():
         gloss=gloss.union(example)
    gloss = gloss.difference( stop_words )

    sentence = set(sentence.split(" "))
    sentence = sentence.difference( stop_words )
    gloss=gloss.intersection(sentence)
    return len( gloss )

def main():
    sentence = input("Enter the Sentence :")
    word = input("Enter the word :")

    lesk = simplified_lesk(word,sentence)
    print (lesk)
    if lesk is not None:
        print ("Definition: ",lesk.definition())
        example=0
        print ("\nExamples:")
        for i in lesk.examples():
            example=example+1
            print (str(example)+'.',i)

if __name__=='__main__':
    main()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\janvi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Enter the Sentence :the bank guarantees to deposits the money
# Enter the word :bank
# Total senses are
# ------------------------
# Synset('bank.n.01')
# 1
# Synset('depository_financial_institution.n.01')
# 8
# Synset('bank.n.03')
# 2
# Synset('bank.n.04')
# 0
# Synset('bank.n.05')
# 0
# Synset('bank.n.06')
# 0
# Synset('bank.n.07')
# 0
# Synset('savings_bank.n.02')
# 2
# Synset('bank.n.09')
# 0
# Synset('bank.n.10')
# 1
# Synset('bank.v.01')
# 0
# Synset('bank.v.02')
# 1
# Synset('bank.v.03')
# 1
# Synset('bank.v.04')
# 0
# Synset('bank.v.05')
# 0
# Synset('deposit.v.02')
# 1
# Synset('bank.v.07')
# 0
# Synset('trust.v.01')
# 0
# --------------------------------
#
# Final Chosen Sense
# Synset('depository_financial_institution.n.01')
# Definition:  a financial institution that accepts deposits and channels the money into lending activities
#
# Examples:
# 1. he cashed a check at the bank
# 2. that bank holds the mortgage on my home
